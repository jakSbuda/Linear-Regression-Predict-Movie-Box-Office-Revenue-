# %% [markdown]
# Data from the-number.com, Movie Production budget, Domestic Gross and Worldwide Gross

# %% [markdown]
# Data cleaned in MS Excel, removed all columns with missing data, incomplete data and inaccutare data, null and rows with zeros.
# Removed Rank, Release Date, Movie title and domestic gross.
# Removed the Dollar sign from all the values and headings.

# %% [markdown]
# **Data Exploration and Visualisation**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7e384028-cd17-4206-a073-bcce32047759" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e384028-cd17-4206-a073-bcce32047759">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cost_revenue_clean.csv to cost_revenue_clean.csv

# %%
df = pd.read_csv('cost_revenue_clean.csv')

# %%
df.head()
# Out:
#    production_budget_usd  worldwide_gross_usd
# 0                1000000                   26
# 1                  10000                  401
# 2                 400000                  423
# 3                 750000                  450
# 4                  10000                  527

# %%
df.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
x = pd.DataFrame(df, columns=['production_budget_usd'])
y = pd.DataFrame(df, columns=['worldwide_gross_usd'])

# %%
x.head()
# Out:
#    production_budget_usd
# 0                1000000
# 1                  10000
# 2                 400000
# 3                 750000
# 4                  10000

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y, alpha = 0.3)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %%
reg = LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Slope theta_1
reg.coef_
# Out:
# array([[3.11150918]])

# %%
# intercepts 
reg.intercept_
# Out:
# array([-7236192.72913958])

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y, alpha = 0.3)
plt.plot(x, reg.predict(x), color='orange', linewidth=4)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %%
# h(x) = -7236192.7 + 3.1115x

# %%
# R^2
reg.score(x,y)
# Out:
# 0.5496485356985729
